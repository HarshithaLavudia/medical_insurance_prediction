# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/insurance.csv')

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.set()
plt.figure(figsize=(6,6))
sns.displot(df['age'])
plt.title('Age Distribution')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='sex', data=df)
plt.title('Sex Distribution')
plt.show()

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.displot(df['bmi'])
plt.title('BMI Distribution')
plt.show()

# %%
df['bmi'].value_counts()
# Out:
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='children', data=df)
plt.title('Children')
plt.show()

# %%
df['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='smoker', data=df)
plt.title('smoker')
plt.show()

# %%
df['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='region', data=df)
plt.title('region')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.displot(df['charges'])
plt.title('Charges Distribution')
plt.show()

# %%
df.replace({'sex':{'male':0,'female':1}}, inplace=True)

df.replace({'smoker':{'yes':0,'no':1}}, inplace=True)

df.replace({'region':{'southeast':0,'southwest':1,'northeast':2,'northwest':3}}, inplace=True)

# %%
X = df.drop(columns='charges', axis=1)
Y = df['charges']

# %%
print(X)
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       0       1
# 1      18    0  33.770         1       1       0
# 2      28    0  33.000         3       1       0
# 3      33    0  22.705         0       1       3
# 4      32    0  28.880         0       1       3
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       1       3
# 1334   18    1  31.920         0       1       2
# 1335   18    1  36.850         0       1       0
# 1336   21    1  25.800         0       1       1
# 1337   61    1  29.070         0       0       3
#
# [1338 rows x 6 columns]

# %%
print(Y)
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1338, 6) (1070, 6) (268, 6)

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred1 = regressor.predict(X_test)

# %%
from sklearn.metrics import precision_score, accuracy_score, recall_score, confusion_matrix, f1_score, mean_squared_error, mean_absolute_error, r2_score

# %%
dt_mse = mean_squared_error(Y_test, y_pred1)
dt_rmse = mean_squared_error(Y_test, y_pred1, squared=False)
dt_mae = mean_absolute_error(Y_test, y_pred1)
dt_r2 = r2_score(Y_test, y_pred1)

# %%
plt.scatter(Y_test, y_pred1, color='blue', label='Predictions', s=7)
plt.scatter(Y_test, Y_test, color='red', label='Actual',s=1)

plt.xlabel('Actual Charges')
plt.ylabel('Predicted Charges')
plt.title('Decision Tree : Actual vs Predicted Charges')
plt.legend()
plt.show()

# Printing metrics
print('Mean Squared Error (MSE):', dt_mse)
print('Root Mean Squared Error (RMSE):', dt_rmse)
print('Mean Absolute Error (MAE):', dt_mae)
print('R-squared (R2) Score:', dt_r2)
# Out:
# Mean Squared Error (MSE): 38337035.48643885
# Root Mean Squared Error (RMSE): 6191.690842285236
# Mean Absolute Error (MAE): 4267.213826730733
# R-squared (R2) Score: 0.7447273869684076

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor()
rf_model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred1 = rf_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
rf_mse = mean_squared_error(Y_test, y_pred1)
rf_rmse = mean_squared_error(Y_test, y_pred1, squared=False)
rf_mae = mean_absolute_error(Y_test, y_pred1)
rf_r2 = r2_score(Y_test, y_pred1)

# %%
plt.scatter(Y_test, y_pred1, color='blue', label='Predictions', s=7)
plt.scatter(Y_test, Y_test, color='red', label='Actual',s=1)

plt.xlabel('Actual Charges')
plt.ylabel('Predicted Charges')
plt.title('Decision Tree : Actual vs Predicted Charges')
plt.legend()
plt.show()

# Printing metrics
print('Mean Squared Error (MSE):', rf_mse)
print('Root Mean Squared Error (RMSE):', rf_rmse)
print('Mean Absolute Error (MAE):', rf_mae)
print('R-squared (R2) Score:', rf_r2)
# Out:
# Mean Squared Error (MSE): 24275640.133692857
# Root Mean Squared Error (RMSE): 4927.031574253696
# Mean Absolute Error (MAE): 2740.4782208204488
# R-squared (R2) Score: 0.8383571913865266

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt_model = DecisionTreeRegressor()
dt_model.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred1 = dt_model.predict(X_test)

# %%
print(y_pred1)
# Out:
# [ 2396.0959   10214.636     9447.3824    1720.3537    8302.53565
#   5400.9805    2789.0574    2198.18985  28923.13692   7201.70085
#  12224.35085   4830.63     18608.262     1131.5066   10043.249
#  13919.8229    2137.6536    6128.79745  20984.0936    7323.734819
#  11353.2276    2331.519    39047.285    20234.85475  38511.6283
#  12029.2867    3558.62025   9704.66805   3987.926     3176.2877
#   6474.013     3594.17085  17626.23951   4243.59005   7726.854
#  14133.03775  39722.7462    5028.1466   18310.742    13937.6665
#   2128.43105  36021.0112    7518.02535   1875.344     6770.1925
#   4889.9995    9620.3307    3875.7341    4753.6368   10601.412
#  26018.95052   1242.26     17352.6803   43254.41795   6500.2359
#  11411.685     2352.96845   7162.0122    2150.469    42124.5153
#  13112.6048    1842.519     2855.43755  42124.5153    1242.26
#  11362.755    12244.531     1877.9294   13352.0998    6664.68595
#  10214.636    14001.2867   10493.9458    6082.405    12644.589
# ...

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
dt_mse = mean_squared_error(Y_test, y_pred1)
dt_rmse = mean_squared_error(Y_test, y_pred1, squared=False)
dt_mae = mean_absolute_error(Y_test, y_pred1)
dt_r2 = r2_score(Y_test, y_pred1)

# %%
plt.scatter(Y_test, y_pred1, color='blue', label='Predictions', s=7)
plt.scatter(Y_test, Y_test, color='red', label='Actual',s=1)

plt.xlabel('Actual Charges')
plt.ylabel('Predicted Charges')
plt.title('Decision Tree : Actual vs Predicted Charges')
plt.legend()
plt.show()

# Printing metrics
print('Mean Squared Error (MSE):', dt_mse)
print('Root Mean Squared Error (RMSE):', dt_rmse)
print('Mean Absolute Error (MAE):', dt_mae)
print('R-squared (R2) Score:', dt_r2)
# Out:
# Mean Squared Error (MSE): 42865517.9824023
# Root Mean Squared Error (RMSE): 6547.176336589866
# Mean Absolute Error (MAE): 3170.428560477612
# R-squared (R2) Score: 0.7145738410527007

# %%
input_data = (19, 1, 27.9, 0, 0, 1)

input_data_as_numpy_array = np.asarray(input_data)

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = dt_model.predict(input_data_reshaped)
print(prediction)

print('The insurance cost is USD ', prediction[0])
# Out:
# [16884.924]
# The insurance cost is USD  16884.924
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
! pip install -U gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 52.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 14.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 39.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.0/139.0 kB 21.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 61.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 20.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 13.6 MB/s eta 0:00:00
# ...

# %%
import gradio as gr

# %%
def medical_ins_predict(age, sex, bmi, children, smoker, region):

  sex_mapping = {'male': 0, 'female': 1}
  sex_numeric = sex_mapping.get(sex.lower(), None)
  if sex_numeric is None:
    raise ValueError("Invalid value for 'sex'. Please provide 'male' or 'female'.")

  smoker_mapping = {'yes': 0, 'no': 1}
  smoker_numeric = smoker_mapping.get(smoker.lower(), None)
  if smoker_numeric is None:
    raise ValueError("Invalid value for 'smoker'. Please provide 'yes' or 'no'.")

  region_mapping = {'southeast': 0, 'southwest': 1, 'northeast' : 2, 'northwest' : 3}
  region_numeric = region_mapping.get(region.lower(), None)
  if region_numeric is None:
    raise ValueError("Invalid value for 'region'.")

  input_data = pd.DataFrame({
      'age' : [age],
      'sex' : [sex_numeric],
      'bmi' : [bmi],
      'children' : [children],
      'smoker' : [smoker_numeric],
      'region' : [region_numeric]
  })

  prediction = dt_model.predict(input_data)
  return prediction

# %%
interface = gr.Interface(
    fn=medical_ins_predict,
    inputs=[
        gr.Number(label="Age"),
        gr.Textbox(lines=1, label="Sex"),
        gr.Number(label="BMI"),
        gr.Number(label="Children"),
        gr.Textbox(lines=1, label="Smoker"),
        gr.Textbox(lines=1, label="Region")
    ],
    outputs=gr.Number(label="Predicted Insurance Money"),
    title="Medical Insurance Predictor",
    description="Enter the below details to predict your medical insurance money"
)

# %%
interface.launch(debug = True)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://a9a246bdd6314b60b6.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://a9a246bdd6314b60b6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
